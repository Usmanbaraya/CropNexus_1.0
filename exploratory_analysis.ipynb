# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("seasonal_crop_recommendation_data.csv")

# %%
df.head()
# Out:
#           Region Soil Type  Temperature (°C)  Rainfall (mm)  Humidity (%)  \
# 0     North-West      Silt              37.4           1353            60
# 1     North-West     Sandy              30.8           1300            88
# 2    South-South     Loamy              25.9            590            73
# 3  North-Central     Sandy              23.8           1912            82
# 4     South-East      Clay              24.5           1545            89
#
#    pH Level  Sunlight Hours/Day  Soil Moisture (%)  Altitude (m)  \
# 0       5.3                   9                 45           618
# 1       5.8                   5                 73           294
# 2       5.3                   6                 47           471
# 3       5.7                   7                 29           121
# 4       7.4                   6                 52           999
#
#   Slope/Topography Crop Planted  Maturation Period (Days)  Crop Type  \
# ...

# %%
print(df['Region'].unique())
print(df['Crop Planted'].unique())
print(df['Soil Type'].unique())
# Out:
# ['north-west' 'south-south' 'north-central' 'south-east' 'south-west'
#  'north-east']
# ['sorghum' 'millet' 'rice' 'maize' 'wheat' 'yam' 'cocoa' 'cassava'
#  'groundnut' 'tomato']
# ['silt' 'sandy' 'loamy' 'clay' 'peaty']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Region                    60000 non-null  object
#  1   Soil Type                 60000 non-null  object
#  2   Temperature (°C)          60000 non-null  float64
#  3   Rainfall (mm)             60000 non-null  int64
#  4   Humidity (%)              60000 non-null  int64
#  5   pH Level                  60000 non-null  float64
#  6   Sunlight Hours/Day        60000 non-null  int64
#  7   Soil Moisture (%)         60000 non-null  int64
#  8   Altitude (m)              60000 non-null  int64
#  9   Slope/Topography          60000 non-null  object
#  10  Crop Planted              60000 non-null  object
#  11  Maturation Period (Days)  60000 non-null  int64
#  12  Crop Type                 60000 non-null  object
# ...

# %%
df.Region.value_counts()
# Out:
# Region
# North-East       10231
# North-Central    10110
# North-West       10021
# South-South       9928
# South-East        9916
# South-West        9794
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
plt.figure(figsize=(7,3))
sns.countplot(data=df,x='Region')
plt.show()

# %%
print(df['Crop Type'].unique())
print(df['Crop Type'].nunique())
# Out:
# ['Grain' 'Legume' 'Cash Crop' 'Cereal' 'Vegetable' 'Root']
# 6

# %%
print(df['Crop Planted'].unique())
print(df['Crop Planted'].nunique())
# Out:
# ['Sorghum' 'Millet' 'Rice' 'Maize' 'Wheat' 'Yam' 'Cocoa' 'Cassava'
#  'Groundnut' 'Tomato']
# 10

# %%
sns.countplot(data=df,x='Crop Planted')
plt.show()

# %%
sns.displot(data=df,x="Temperature (°C)")
plt.show()

# %%
sns.scatterplot(data=df,x='Temperature (°C)',y='Rainfall (mm)')
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                           Temperature (°C)  Rainfall (mm)  Humidity (%)  \
# Temperature (°C)                  1.000000      -0.001681     -0.003706
# Rainfall (mm)                    -0.001681       1.000000      0.005440
# Humidity (%)                     -0.003706       0.005440      1.000000
# pH Level                          0.002255       0.008292     -0.003259
# Sunlight Hours/Day                0.001844      -0.000942      0.002628
# Soil Moisture (%)                 0.001483      -0.005435     -0.003672
# Altitude (m)                      0.005342       0.001096     -0.002097
# Maturation Period (Days)         -0.000453      -0.000646     -0.000135
# Market Demand (Price/kg)          0.004164      -0.004420     -0.002412
# Historical Yield (kg/ha)         -0.000228      -0.008745      0.007030
#
#                           pH Level  Sunlight Hours/Day  Soil Moisture (%)  \
# Temperature (°C)          0.002255            0.001844           0.001483
# ...

# %%
df.columns
# Out:
# Index(['Region', 'Soil Type', 'Temperature (°C)', 'Rainfall (mm)',
#        'Humidity (%)', 'pH Level', 'Sunlight Hours/Day', 'Soil Moisture (%)',
#        'Altitude (m)', 'Slope/Topography', 'Crop Planted',
#        'Maturation Period (Days)', 'Crop Type', 'Soil Requirement',
#        'Planting Season', 'Irrigation Availability', 'Fertilizer Requirement',
#        'Pests/Disease Risk', 'Market Demand (Price/kg)',
#        'Historical Yield (kg/ha)'],
#       dtype='object')
